# %% [markdown]
# # ATML Project Report
# ## American Sign Language Recognition

# %% [markdown]
# Dataset: http://empslocal.ex.ac.uk/people/staff/np331/index.php?section=FingerSpellingDataset
#
# Paper: Alphabet Sign Language Image Classification Using Deep Learning (https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=8650241)
#
#
# Goal: Get better result than the proposed solution of the paper in american sign language recognition.

# %% [markdown]
# ## Approach description / Task description

# %% [markdown]
# ## Results / Analysis

# %% [markdown]
# ### Learning Curves

# %%
train_loss = []
train_accuracy = []
val_loss = []
val_accuracy = []

with open('results/main.sh.o32224', 'r') as f:
    for line in f:
        splitted = line.split()
        if (splitted[0] != 'Test'):
            train_loss.append(float(splitted[3].replace(",", "")))
            train_accuracy.append(float(splitted[5].replace(",", "")))
            val_loss.append(float(splitted[7].replace(",", "")))
            val_accuracy.append(float(splitted[9].replace(",", "")))

# %%
#Plotting loss
import numpy as np
import matplotlib.pyplot as plt

n_epochs = 300
plt.figure()
plt.plot(np.arange(n_epochs), train_loss)
plt.plot(np.arange(n_epochs), val_loss)
plt.legend(['train_loss', 'val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss value')
plt.title('Train/Val loss')

plt.show()

# %%
#Plotting accuracy
import numpy as np
import matplotlib.pyplot as plt

n_epochs = 300
plt.figure()
plt.plot(np.arange(n_epochs), train_accuracy)
plt.plot(np.arange(n_epochs), val_accuracy)
plt.legend(['train_accuracy', 'val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Train/Val accuracy')

plt.show()

# %% [markdown]
# ## Guide to use code

# %%
# Code here or import from external python file

# %% [markdown]
# ### Example of use with step by step instructions
